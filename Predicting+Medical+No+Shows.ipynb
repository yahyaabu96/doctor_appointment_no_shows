# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Desktop/KaggleV2-May-2016.csv')

# %%
data.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
data.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show'],
#       dtype='object')

# %%
data.drop('AppointmentID', axis=1, inplace = True)

# %%
data.drop('PatientId', axis=1, inplace = True)

# %%
data
# Out:
#        Gender          ScheduledDay        AppointmentDay  Age  \
# 0           F  2016-04-29T18:38:08Z  2016-04-29T00:00:00Z   62
# 1           M  2016-04-29T16:08:27Z  2016-04-29T00:00:00Z   56
# 2           F  2016-04-29T16:19:04Z  2016-04-29T00:00:00Z   62
# 3           F  2016-04-29T17:29:31Z  2016-04-29T00:00:00Z    8
# 4           F  2016-04-29T16:07:23Z  2016-04-29T00:00:00Z   56
# 5           F  2016-04-27T08:36:51Z  2016-04-29T00:00:00Z   76
# 6           F  2016-04-27T15:05:12Z  2016-04-29T00:00:00Z   23
# 7           F  2016-04-27T15:39:58Z  2016-04-29T00:00:00Z   39
# 8           F  2016-04-29T08:02:16Z  2016-04-29T00:00:00Z   21
# 9           F  2016-04-27T12:48:25Z  2016-04-29T00:00:00Z   19
# 10          F  2016-04-27T14:58:11Z  2016-04-29T00:00:00Z   30
# 11          M  2016-04-26T08:44:12Z  2016-04-29T00:00:00Z   29
# 12          F  2016-04-28T11:33:51Z  2016-04-29T00:00:00Z   22
# 13          M  2016-04-28T14:52:07Z  2016-04-29T00:00:00Z   28
# ...

# %%
date_booked = []

for i in data['ScheduledDay']:
    date_booked.append(i[0:10])

# %%
date_booked = pd.DataFrame(date_booked)

# %%
data['date_booked'] = date_booked

# %%
appointment_day = []

for i in data['AppointmentDay']:
    appointment_day.append(i[0:10])

# %%
# pd.DataFrame(appointment_day)

# %%
data['Appointment_Date'] = appointment_day

# %%
type(data['Appointment_Date'])
# Out:
# pandas.core.series.Series

# %%
# pd.to_datetime(data['Appointment_Date'])

# %%
# pd.to_datetime(data['date_booked'])

# %%
type(data['date_booked'])
# Out:
# pandas.core.series.Series

# %%
# data['Neighbourhood'].unique()

# %%
area = data.groupby('Neighbourhood')

# %%
area = area.count()

# %%
area
# Out:
#                      Gender  ScheduledDay  AppointmentDay   Age  Scholarship  \
# Neighbourhood
# AEROPORTO                 8             8               8     8            8
# ANDORINHAS             2262          2262            2262  2262         2262
# ANTÔNIO HONÓRIO         271           271             271   271          271
# ARIOVALDO FAVALESSA     282           282             282   282          282
# BARRO VERMELHO          423           423             423   423          423
# BELA VISTA             1907          1907            1907  1907         1907
# BENTO FERREIRA          858           858             858   858          858
# BOA VISTA               312           312             312   312          312
# BONFIM                 2773          2773            2773  2773         2773
# CARATOÍRA              2565          2565            2565  2565         2565
# CENTRO                 3334          3334            3334  3334         3334
# ...

# %%
np.max(area['Gender'])
# Out:
# 7717

# %%
area[area['Gender'] == 7717]
# Out:
#                 Gender  ScheduledDay  AppointmentDay   Age  Scholarship  \
# Neighbourhood
# JARDIM CAMBURI    7717          7717            7717  7717         7717
#
#                 Hipertension  Diabetes  Alcoholism  Handcap  SMS_received  \
# Neighbourhood
# JARDIM CAMBURI          7717      7717        7717     7717          7717
#
#                 No-show  date_booked  Appointment_Date
# Neighbourhood
# JARDIM CAMBURI     7717         7717              7717

# %%
df = data[data['Neighbourhood'] == 'JARDIM CAMBURI']

# %%
df.drop('ScheduledDay', axis = 1, inplace = True)
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.drop('AppointmentDay', axis = 1, inplace = True)
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.drop('Neighbourhood', axis = 1, inplace = True)
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Gender'].replace('F',0, inplace = True)
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3924: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df['Gender'].replace('M',1, inplace = True)
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3924: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df['No-show'].replace('No', 0, inplace = True)
df['No-show'].replace('Yes',1, inplace = True)
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3924: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
# df['day_difference'] = df['Appointment_Date'] - df['date_booked']

# %%
# for i in data['Appointment_Date']:
#     print(type(i))

# %%
df['Appointment_Date'] = pd.to_datetime(data['Appointment_Date'])
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['date_booked'] = pd.to_datetime(data['date_booked'])
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Diff'] = df['Appointment_Date'] - df['date_booked']
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ds = []

for i in df['Diff']:
    ds.append(i)

# %%
df['Diff'] = ds
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# data['Diff']

# %%
df['Diff'] = (df['Diff'] / np.timedelta64(1, 'D')).astype(int)
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Scholarship', 'Hipertension', 'Diabetes',
#        'Alcoholism', 'Handcap', 'SMS_received', 'No-show', 'date_booked',
#        'Appointment_Date', 'Diff'],
#       dtype='object')

# %%
df.columns = [['Gender', 'Age', 'Scholarship', 'Hipertension', 'Diabetes',
       'Alcoholism', 'Handcap', 'SMS_received', 'No-show', 'date_booked',
       'Appointment_Date', 'Days_waited_for_appt']]

# %%
df.drop('date_booked', axis = 1, inplace = True)
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.drop('Appointment_Date', axis = 1, inplace = True)
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
X = df.drop('No-show', axis = 1)
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
y = df['No-show']

# %%
df
# Out:
#         Gender  Age  Scholarship  Hipertension  Diabetes  Alcoholism  Handcap  \
# 72           0   61            0             0         0           0        0
# 398          0   43            0             0         0           0        0
# 444          1   13            0             0         0           0        0
# 445          0   65            0             1         0           0        0
# 446          0   60            0             0         0           0        0
# 447          0   21            0             0         0           0        0
# 448          1   12            0             0         0           0        0
# 449          0   11            0             0         0           0        0
# 450          1   12            0             0         0           0        0
# 451          0   32            0             0         0           0        0
# 452          1   13            0             0         0           0        0
# ...

# %%
df.dropna(inplace=True)
# Out:
# /Users/Yahya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X = df.drop('No-show', axis = 1)
y = df['No-show']

# %%
knn.fit(X,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %%
X.columns
# Out:
# Index(['Gender', 'Age', 'Scholarship', 'Hipertension', 'Diabetes',
#        'Alcoholism', 'Handcap', 'SMS_received', 'Days_waited_for_appt'],
#       dtype='object')

# %%
knn.predict([[0,28,0,0,0,0,0,1,21]])
# Out:
# array([1])

# %%
noshows = df[df['No-show'] == 1]

# %%
sns.distplot(noshows['Days_waited_for_appt'])
plt.show()

# %%
np.mean(noshows['Days_waited_for_appt'])
# Out:
# 27.529692832764503

# %%
turned_up = df[df['No-show'] == 0]

# %%
np.mean(turned_up['Days_waited_for_appt'])
# Out:
# 16.706653870761357

# %%
sns.distplot(turned_up['Days_waited_for_appt'])
plt.show()

# %%
turned_up.shape
# Out:
# (6252, 10)

# %%
noshows.shape
# Out:
# (1465, 10)

# %%
no_shows_as_a_pct = 1465/6252

# %%
no_shows_as_a_pct
# Out:
# 0.23432501599488165
